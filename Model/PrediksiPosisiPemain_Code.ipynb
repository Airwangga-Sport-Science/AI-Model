# %%
import pandas as pd 

df = pd.read_csv(r'D:\Program\Airwangga Sport Science\AI Model\AI-Model\Data\FM 2023.csv') #Sesuaikan Path dengan lokasi Dataset di masing-masing device

# %%
df.set_index(df['Name'].values, inplace=True)

# %%
df
# Out:
#                                   Name  Position  Age   ca   pa
# Kevin De Bruyne        Kevin De Bruyne  M/AM RLC   31  189  189  \
# Kylian Mbappé            Kylian Mbappé   AM/S RL   23  188  197
# Robert Lewandowski  Robert Lewandowski         S   33  186  190
# Erling Haaland          Erling Haaland         S   22  185  195
# Mohamed Salah            Mohamed Salah   AM/S RL   30  185  187
# ...                                ...       ...  ...  ...  ...
# Joe Ashton                  Joe Ashton       D L   16   45  135
# River Ries                  River Ries         S   17   45  135
# Halilcan Doğan          Halilcan Doğan       D C   23   45  -75
# Adijat Sefer              Adijat Sefer         S   17   45  135
# Linus Urban                Linus Urban         S   17   45  135
#
#                        Nationality                        Club  Corners
# Kevin De Bruyne            Belgium             Manchester City       14  \
# Kylian Mbappé               France         Paris Saint-Germain       13
# Robert Lewandowski          Poland                   Barcelona        3
# Erling Haaland      Norway,England             Manchester City        7
# Mohamed Salah                Egypt                   Liverpool       12
# ...                            ...                         ...      ...
# Joe Ashton                 England                     Burnley        3
# River Ries                 Germany               Karlsruher SC        2
# Halilcan Doğan              Turkey  Osmaniyespor Futbol Kulübü        1
# Adijat Sefer               Germany              TSG Hoffenheim        3
# Linus Urban                Germany            SV Werder Bremen        4
#
#                     Crossing  Dribbling  ...  World reputation
# Kevin De Bruyne           19         15  ...              9400  \
# Kylian Mbappé             13         18  ...              9248
# Robert Lewandowski         8         13  ...              9250
# Erling Haaland            10         14  ...              8750
# Mohamed Salah             14         17  ...              8750
# ...                      ...        ...  ...               ...
# Joe Ashton                 4          5  ...               236
# River Ries                 2         11  ...               462
# Halilcan Doğan             1          1  ...              1145
# Adijat Sefer               4         12  ...               474
# Linus Urban                2         10  ...               176
#
#                                              Race  RCA  Colour of skin
# Kevin De Bruyne                 Northern_European  181               4  \
# Kylian Mbappé                   African_Caribbean  172              13
# Robert Lewandowski              Northern_European  183               3
# Erling Haaland                  Northern_European  185               2
# Mohamed Salah       North_African__Middle_Eastern  181               9
# ...                                           ...  ...             ...
# Joe Ashton                      Northern_European   41               3
# River Ries                      Northern_European   33             255
# Halilcan Doğan                  Northern_European   41               3
# Adijat Sefer                    Northern_European   40             255
# Linus Urban                     Northern_European   41             255
#
#                     Date of birth  Number of national team appearances
# Kevin De Bruyne         1991/6/28                                   91  \
# Kylian Mbappé          1998/12/20                                   57
# Robert Lewandowski      1988/8/21                                  132
# Erling Haaland          2000/7/21                                   21
# Mohamed Salah           1992/6/15                                   85
# ...                           ...                                  ...
# Joe Ashton              2006/6/26                                    0
# River Ries               2005/4/3                                    0
# Halilcan Doğan          1999/2/11                                    0
# Adijat Sefer            2005/1/20                                    0
# Linus Urban            2004/11/20                                    0
#
#                     Goals scored for the national team     Salary
# Kevin De Bruyne                                     24   394372.0  \
# Kylian Mbappé                                       27  1035616.0
# Robert Lewandowski                                  76   345204.0
# Erling Haaland                                      20   394372.0
# Mohamed Salah                                       47   405971.0
# ...                                                ...        ...
# Joe Ashton                                           0      203.0
# River Ries                                           0      402.0
# Halilcan Doğan                                       0       82.0
# Adijat Sefer                                         0      646.0
# Linus Urban                                          0      646.0
#
#                     Rental club         UID
# Kevin De Bruyne             NaN    18004457
# Kylian Mbappé               NaN    85139014
# Robert Lewandowski          NaN      719601
# Erling Haaland              NaN    29179241
# Mohamed Salah               NaN    98028755
# ...                         ...         ...
# Joe Ashton                  NaN  2000210572
# River Ries                  NaN  2000197059
# Halilcan Doğan              NaN  2000047739
# Adijat Sefer                NaN  2000197383
# Linus Urban                 NaN  2000194686
#
# [8452 rows x 98 columns]

# %%
X = df[['Corners', 'Crossing', 'Dribbling', 'Finishing', 'First Touch', 'Free Kick Taking', 'Heading', 'Long Shots',
   'Long Throws', 'Passing', 'Penalty Taking', 'Tackling', 'Acceleration', 'Agility',
    'Jumping Reach', 'Natural Fitness', 'Pace', 'Stamina', 'Strength']]
y = df[['GK', 'DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'ML', 'MC', 'AML', 'AMC', 'AMR', 'ST']]

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
vectors = X.values
scaled_rows = scaler.fit_transform(vectors.T).T
X_normalized = pd.DataFrame(data = scaled_rows, columns = X.columns)

# %%
X_normalized.set_index(df['Name'].values, inplace=True)

# %%
X_normalized
# Out:
#                      Corners  Crossing  Dribbling  Finishing  First Touch
# Kevin De Bruyne     0.615385  1.000000   0.692308   0.769231     0.769231  \
# Kylian Mbappé       0.562500  0.562500   0.875000   0.812500     0.875000
# Robert Lewandowski  0.000000  0.294118   0.588235   0.941176     0.882353
# Erling Haaland      0.142857  0.357143   0.642857   0.928571     0.785714
# Mohamed Salah       0.500000  0.666667   0.916667   0.916667     0.916667
# ...                      ...       ...        ...        ...          ...
# Joe Ashton          0.133333  0.200000   0.266667   0.200000     0.200000
# River Ries          0.090909  0.090909   0.909091   0.909091     0.909091
# Halilcan Doğan      0.000000  0.000000   0.000000   0.090909     0.272727
# Adijat Sefer        0.181818  0.272727   1.000000   0.545455     0.636364
# Linus Urban         0.250000  0.083333   0.750000   1.000000     0.583333
#
#                     Free Kick Taking   Heading  Long Shots  Long Throws
# Kevin De Bruyne             0.846154  0.000000    0.846154     0.076923  \
# Kylian Mbappé               0.500000  0.187500    0.562500     0.000000
# Robert Lewandowski          0.705882  0.823529    0.529412     0.000000
# Erling Haaland              0.571429  0.714286    0.571429     0.000000
# Mohamed Salah               0.500000  0.333333    0.583333     0.000000
# ...                              ...       ...         ...          ...
# Joe Ashton                  0.000000  0.333333    0.000000     0.266667
# River Ries                  0.090909  0.454545    0.000000     0.000000
# Halilcan Doğan              0.000000  1.000000    0.181818     0.000000
# Adijat Sefer                0.181818  1.000000    0.272727     0.000000
# Linus Urban                 0.250000  1.000000    0.333333     0.000000
#
#                      Passing  Penalty Taking  Tackling  Acceleration
# Kevin De Bruyne     0.923077        0.769231  0.230769      0.692308  \
# Kylian Mbappé       0.687500        0.875000  0.000000      1.000000
# Robert Lewandowski  0.588235        1.000000  0.235294      0.647059
# Erling Haaland      0.571429        0.857143  0.142857      0.857143
# Mohamed Salah       0.750000        0.916667  0.083333      1.000000
# ...                      ...             ...       ...           ...
# Joe Ashton          0.133333        0.000000  0.733333      0.800000
# River Ries          0.181818        0.454545  0.000000      0.909091
# Halilcan Doğan      0.272727        0.000000  1.000000      0.909091
# Adijat Sefer        0.272727        0.090909  0.181818      1.000000
# Linus Urban         0.333333        0.666667  0.083333      0.583333
#
#                      Agility  Jumping Reach  Natural Fitness      Pace
# Kevin De Bruyne     0.538462       0.307692         0.769231  0.615385  \
# Kylian Mbappé       0.750000       0.250000         0.687500  1.000000
# Robert Lewandowski  0.588235       0.705882         1.000000  0.647059
# Erling Haaland      0.785714       0.928571         1.000000  1.000000
# Mohamed Salah       0.833333       0.166667         0.916667  1.000000
# ...                      ...            ...              ...       ...
# Joe Ashton          0.600000       0.666667         1.000000  0.733333
# River Ries          0.636364       0.454545         1.000000  0.727273
# Halilcan Doğan      0.818182       0.909091         0.727273  0.818182
# Adijat Sefer        0.818182       0.818182         0.727273  1.000000
# Linus Urban         0.583333       0.250000         0.500000  0.583333
#
#                      Stamina  Strength
# Kevin De Bruyne     0.846154  0.538462
# Kylian Mbappé       0.625000  0.437500
# Robert Lewandowski  0.882353  0.764706
# Erling Haaland      0.642857  0.857143
# Mohamed Salah       0.750000  0.750000
# ...                      ...       ...
# Joe Ashton          0.333333  0.400000
# River Ries          0.545455  0.454545
# Halilcan Doğan      0.181818  0.272727
# Adijat Sefer        0.454545  0.636364
# Linus Urban         0.583333  0.500000
#
# [8452 rows x 19 columns]

# %%
#Non Neural Network Regression
import matplotlib
from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle
from matplotlib.colors import ListedColormap
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

Knn=KNeighborsRegressor()                          # Accept default parameters
LR=LinearRegression()
RF=RandomForestRegressor(max_depth=None, max_features=None, random_state=42)


Knn.fit(X_normalized, y)   
LR.fit(X_normalized, y) 
RF.fit(X_normalized, y)
# Out:
# RandomForestRegressor(max_features=None, random_state=42)

# %%
#Neural Network Regression

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, InputLayer, Flatten
from tensorflow.keras.callbacks import EarlyStopping

NNetModel = Sequential()

NNetModel.add(Dense(len(X_normalized.columns), activation='relu', input_dim=len(X_normalized.columns)))
NNetModel.add(BatchNormalization())
NNetModel.add(Dense(16, activation='relu'))
NNetModel.add(Dropout(0.2))
NNetModel.add(Dense(32, activation='relu'))
NNetModel.add(Dropout(0.5))
NNetModel.add(Dense(len(y.columns), activation='linear'))

NNetModel.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=10)
NNetModel.fit(X_normalized.values, y.values, batch_size=64, epochs=4000, verbose=1, validation_split=0.3, callbacks=[es])
# Out:
# Epoch 1/4000
# 93/93 [==============================] - 3s 10ms/step - loss: 66.8858 - mse: 66.8858 - val_loss: 48.1528 - val_mse: 48.1528
# Epoch 2/4000
# 93/93 [==============================] - 1s 11ms/step - loss: 44.5760 - mse: 44.5760 - val_loss: 36.6031 - val_mse: 36.6031
# Epoch 3/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.6114 - mse: 23.6114 - val_loss: 20.5746 - val_mse: 20.5746
# Epoch 87/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.4922 - mse: 23.4922 - val_loss: 20.5412 - val_mse: 20.5412
# Epoch 88/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.4392 - mse: 23.4392 - val_loss: 20.8075 - val_mse: 20.8075
# Epoch 89/4000
# 93/93 [==============================] - 0s 5ms/step - loss: 23.5542 - mse: 23.5542 - val_loss: 20.8375 - val_mse: 20.8375
# Epoch 90/4000
# 93/93 [==============================] - 0s 5ms/step - loss: 23.6372 - mse: 23.6372 - val_loss: 21.0086 - val_mse: 21.0086
# Epoch 91/4000
# 93/93 [==============================] - 0s 5ms/step - loss: 23.2919 - mse: 23.2919 - val_loss: 20.9817 - val_mse: 20.9817
# Epoch 92/4000
# 93/93 [==============================] - 1s 10ms/step - loss: 23.4735 - mse: 23.4735 - val_loss: 21.5162 - val_mse: 21.5162
# Epoch 93/4000
# 93/93 [==============================] - 1s 7ms/step - loss: 23.3657 - mse: 23.3657 - val_loss: 20.6858 - val_mse: 20.6858
# Epoch 94/4000
# 93/93 [==============================] - 1s 7ms/step - loss: 23.5904 - mse: 23.5904 - val_loss: 20.9432 - val_mse: 20.9432
# Epoch 95/4000
# 93/93 [==============================] - 1s 7ms/step - loss: 23.5940 - mse: 23.5940 - val_loss: 20.8690 - val_mse: 20.8690
# Epoch 96/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.3062 - mse: 23.3062 - val_loss: 20.9850 - val_mse: 20.9850
# Epoch 97/4000
# 93/93 [==============================] - 1s 8ms/step - loss: 23.2888 - mse: 23.2888 - val_loss: 20.4855 - val_mse: 20.4855
# Epoch 98/4000
# 93/93 [==============================] - 1s 8ms/step - loss: 23.3702 - mse: 23.3702 - val_loss: 21.0237 - val_mse: 21.0237
# Epoch 99/4000
# 93/93 [==============================] - 1s 9ms/step - loss: 23.2857 - mse: 23.2857 - val_loss: 20.7202 - val_mse: 20.7202
# Epoch 100/4000
# 93/93 [==============================] - 1s 8ms/step - loss: 23.4002 - mse: 23.4002 - val_loss: 20.9648 - val_mse: 20.9648
# Epoch 101/4000
# 93/93 [==============================] - 1s 7ms/step - loss: 23.2619 - mse: 23.2619 - val_loss: 20.9507 - val_mse: 20.9507
# Epoch 102/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.1724 - mse: 23.1724 - val_loss: 20.8198 - val_mse: 20.8198
# Epoch 103/4000
# 93/93 [==============================] - 1s 9ms/step - loss: 23.2528 - mse: 23.2528 - val_loss: 20.9732 - val_mse: 20.9732
# Epoch 104/4000
# 93/93 [==============================] - 1s 9ms/step - loss: 22.7998 - mse: 22.7998 - val_loss: 20.9077 - val_mse: 20.9077
# Epoch 105/4000
# 93/93 [==============================] - 1s 11ms/step - loss: 23.2587 - mse: 23.2587 - val_loss: 20.9155 - val_mse: 20.9155
# Epoch 106/4000
# 93/93 [==============================] - 1s 8ms/step - loss: 23.1453 - mse: 23.1453 - val_loss: 21.2695 - val_mse: 21.2695
# Epoch 107/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.2031 - mse: 23.2031 - val_loss: 20.6329 - val_mse: 20.6329
# Epoch 108/4000
# 93/93 [==============================] - 1s 7ms/step - loss: 23.2069 - mse: 23.2069 - val_loss: 20.5234 - val_mse: 20.5234
# Epoch 109/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.1503 - mse: 23.1503 - val_loss: 20.7211 - val_mse: 20.7211
# Epoch 110/4000
# 93/93 [==============================] - 1s 7ms/step - loss: 22.8817 - mse: 22.8817 - val_loss: 20.6679 - val_mse: 20.6679
# Epoch 111/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.0296 - mse: 23.0296 - val_loss: 20.7551 - val_mse: 20.7551
# Epoch 112/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.1369 - mse: 23.1369 - val_loss: 20.9010 - val_mse: 20.9010
# Epoch 113/4000
# 93/93 [==============================] - 1s 6ms/step - loss: 23.0059 - mse: 23.0059 - val_loss: 20.7260 - val_mse: 20.7260
# Epoch 114/4000
# 93/93 [==============================] - 1s 7ms/step - loss: 23.2401 - mse: 23.2401 - val_loss: 20.7395 - val_mse: 20.7395
# Epoch 114: early stopping

# %%
def predict_player_position(player_name, model):

    positions = model.predict(X_normalized.loc[[player_name]].values)

    R_scaler = preprocessing.MinMaxScaler(feature_range=(1, 20))
    vectors = pd.DataFrame(positions.reshape(1,13), columns=y.columns).values
    scaled_rows = R_scaler.fit_transform(vectors.T).T

    results = pd.DataFrame({'Position':y.columns, 'Real':y.loc[player_name], 'Predicted':scaled_rows[0], 'Difference':y.loc[player_name]-scaled_rows[0]})

    return results.nlargest(n=3, columns=['Predicted'])

# %%
import numpy as np
def predict_and_show(player_name, model):
    results = predict_player_position(player_name, model)
    print(results)
    predicted = model.predict(X_normalized.values)
    mse = np.mean((y.values - predicted) ** 2)
    print("\nMSE:", mse)

# %%
predict_and_show('Erling Haaland', NNetModel)
# Out:
# 1/1 [==============================] - 0s 474ms/step
#     Position  Real  Predicted  Difference
# ST        ST    20  19.999998    0.000002
# AML      AML     1   9.246912   -8.246912
# AMR      AMR     1   8.917465   -7.917465
# 265/265 [==============================] - 1s 3ms/step
#
# MSE: 18.895117451150977

# %%
predict_and_show('Erling Haaland', RF)
# Out:
#     Position  Real  Predicted  Difference
# ST        ST    20      20.00        0.00
# AML      AML     1       4.01       -3.01
# AMR      AMR     1       3.82       -2.82
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# MSE: 2.5978246869198003

# %%
predict_and_show('Erling Haaland', LR)
# Out:
#     Position  Real  Predicted    Difference
# ST        ST    20  20.000000 -3.552714e-15
# AML      AML     1  12.036797 -1.103680e+01
# AMR      AMR     1  11.886111 -1.088611e+01
#
# MSE: 22.45069513417556
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predict_and_show('Erling Haaland', Knn)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
#     Position  Real  Predicted  Difference
# ST        ST    20       20.0         0.0
# AML      AML     1       12.2       -11.2
# AMR      AMR     1       11.8       -10.8
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# MSE: 13.898808839054935
