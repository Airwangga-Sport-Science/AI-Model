# %% [markdown]
# # Data Understanding

# %%
import pandas as pd 

df = pd.read_csv(r'C:\Program Files (x86)\New folder\AI-Model\Data\FM 2023.csv')

# %%
df
# Out:
#                     Name  Position  Age   ca   pa     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31  189  189         Belgium
# 1          Kylian Mbappé   AM/S RL   23  188  197          France
# 2     Robert Lewandowski         S   33  186  190          Poland
# 3         Erling Haaland         S   22  185  195  Norway,England
# 4          Mohamed Salah   AM/S RL   30  185  187           Egypt
# ...                  ...       ...  ...  ...  ...             ...
# 8447          Joe Ashton       D L   16   45  135         England
# 8448          River Ries         S   17   45  135         Germany
# 8449      Halilcan Doğan       D C   23   45  -75          Turkey
# 8450        Adijat Sefer         S   17   45  135         Germany
# 8451         Linus Urban         S   17   45  135         Germany
#
#                             Club  Corners  Crossing  Dribbling  ...  \
# 0                Manchester City       14        19         15  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8452 entries, 0 to 8451
# Data columns (total 98 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Name                                 8452 non-null   object
#  1   Position                             8452 non-null   object
#  2   Age                                  8452 non-null   int64
#  3   ca                                   8452 non-null   int64
#  4   pa                                   8452 non-null   int64
#  5   Nationality                          8452 non-null   object
#  6   Club                                 8345 non-null   object
#  7   Corners                              8452 non-null   int64
#  8   Crossing                             8452 non-null   int64
#  9   Dribbling                            8452 non-null   int64
#  10  Finishing                            8452 non-null   int64
# ...

# %%
selected_skills_pos = ["Name", "Corners", "Crossing", "Dribbling", "Finishing", "First Touch",
    "Free Kick Taking", "Heading", "Long Shots", "Passing", "Tackling",
    "Technique", "Concentration", "Vision", "Decision", "Determination",
    "Position.1","Teamwork", "Balance", "Natural Fitness", "Pace",
    "Stamina", "Strength", "Communication", "Reflexes", 'Left Foot', 'Right Foot', "GK", "DL", "DC", "DR", "WBL", 
    "WBR", "DM", "MR", "ML", "MC", "AML", "AMC", "AMR", "ST"
]

# %%
df = df[selected_skills_pos]

# %% [markdown]
# ## 1. Describe Data

# %%
df
# Out:
#                     Name  Corners  Crossing  Dribbling  Finishing  \
# 0        Kevin De Bruyne       14        19         15         16
# 1          Kylian Mbappé       13        13         18         17
# 2     Robert Lewandowski        3         8         13         19
# 3         Erling Haaland        7        10         14         18
# 4          Mohamed Salah       12        14         17         17
# ...                  ...      ...       ...        ...        ...
# 8447          Joe Ashton        3         4          5          4
# 8448          River Ries        2         2         11         11
# 8449      Halilcan Doğan        1         1          1          2
# 8450        Adijat Sefer        3         4         12          7
# 8451         Linus Urban        4         2         10         13
#
#       First Touch  Free Kick Taking  Heading  Long Shots  Passing  ...  WBL  \
# 0              16                17        6          17       18  ...    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8452 entries, 0 to 8451
# Data columns (total 41 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              8452 non-null   object
#  1   Corners           8452 non-null   int64
#  2   Crossing          8452 non-null   int64
#  3   Dribbling         8452 non-null   int64
#  4   Finishing         8452 non-null   int64
#  5   First Touch       8452 non-null   int64
#  6   Free Kick Taking  8452 non-null   int64
#  7   Heading           8452 non-null   int64
#  8   Long Shots        8452 non-null   int64
#  9   Passing           8452 non-null   int64
#  10  Tackling          8452 non-null   int64
#  11  Technique         8452 non-null   int64
#  12  Concentration     8452 non-null   int64
#  13  Vision            8452 non-null   int64
#  14  Decision          8452 non-null   int64
#  15  Determination     8452 non-null   int64
# ...

# %%
df.describe()
# Out:
#            Corners     Crossing    Dribbling    Finishing  First Touch  \
# count  8452.000000  8452.000000  8452.000000  8452.000000  8452.000000
# mean      8.140558     9.435045    10.819569     9.170611    12.039754
# std       3.366027     3.429934     3.574914     3.526125     2.201608
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       6.000000     7.000000     9.000000     7.000000    11.000000
# 50%       8.000000    10.000000    12.000000     9.000000    12.000000
# 75%      11.000000    12.000000    13.000000    12.000000    13.000000
# max      20.000000    19.000000    20.000000    19.000000    20.000000
#
#        Free Kick Taking      Heading   Long Shots      Passing     Tackling  \
# count       8452.000000  8452.000000  8452.000000  8452.000000  8452.000000
# mean           8.626242     9.764316     9.445102    12.044723     9.456342
# std            3.183615     3.505773     3.397667     2.003343     4.012802
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def create_statistic_bar_chart(data, selected_columns, statistics):
    plt.figure(figsize=(14, 10))

    filtered_data = data[selected_columns]

    statistical_data = filtered_data.describe().transpose()
    statistical_data = statistical_data[statistics]
    statistical_data = statistical_data.reset_index()

    statistical_data = pd.melt(statistical_data, id_vars="index", var_name="Statistic", value_name="Value")
    statistical_data = statistical_data.rename(columns={"index": "Column"})

    ax = sns.barplot(x="Statistic", y="Value", hue="Column", data=statistical_data, palette="Set3")
    plt.title("Statistical Description")
    plt.xlabel("Statistic")
    plt.ylabel("Value")
    plt.xticks(rotation=0)
    plt.legend(title="Column")

    for p in ax.patches:
        value = p.get_height()
        x_position = p.get_x() + p.get_width() / 2.
        y_position = value + 1  # Adjust the vertical position
        ax.annotate(f'{value:.2f}', (x_position, y_position),
                    ha='center', va='center', fontsize=10, color='black')

    plt.show()

# %% [markdown]
# #### "Corners", "Crossing", "Dribbling", "Finishing"

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["Corners", "Crossing", "Dribbling", "Finishing"]
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %% [markdown]
# #### "First Touch", "Free Kick Taking", "Heading", "Long Shots"

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["First Touch", "Free Kick Taking", "Heading", "Long Shots"]
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %% [markdown]
# #### "Vision", "Decision", "Determination", "Position.1"

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["Vision", "Decision", "Determination", "Position.1"]
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %% [markdown]
# #### "Teamwork", "Balance", "Natural Fitness", "Pace"

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["Teamwork", "Balance", "Natural Fitness", "Pace"]
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["Stamina", "Strength", 'Left Foot', 'Right Foot']
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["DL", "DC", "DR", "WBL", "WBR"]
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["DM", "ML", "MC", "MR"]
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %%
# Specify the columns you want to include in the statistical analysis
selected_columns = ["AML", "AMC", "AMR", "ST"]
selected_statistics = ["mean", "std", "25%", "50%", "75%", "min", "max"]

# Create the statistical bar chart with improved annotations for the selected columns
create_statistic_bar_chart(df, selected_columns, selected_statistics)

# %% [markdown]
# ## 2. Explore Data

# %% [markdown]
# ### 2.1. Univariate Analysis

# %%
def plot_player_value_distribution(df, positions, thresholds, legend_fontsize):
    """
    Plot the distribution of player values for each position in a grid of separate histograms,
    add red lines at the specified thresholds, and display the number of players above each threshold for each position.

    Parameters:
    df (DataFrame): The DataFrame containing player positions and values.
    positions (list): A list of position column names.
    thresholds (list): A list of threshold values.
    legend_fontsize (int): Font size for the legend text.

    Returns:
    None
    """
    num_positions = len(positions)
    num_cols = 3  # Number of columns in the grid
    num_rows = (num_positions + num_cols - 1) // num_cols  # Calculate the number of rows needed

    # Define colors for the thresholds
    threshold_colors = ['orange', 'red']

    # Create a grid of subplots
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(25, 20))
    fig.suptitle('Distribution of Player Values by Position', fontsize=16)

    for i, position in enumerate(positions):
        row = i // num_cols
        col = i % num_cols

        position_data = df[position]

        ax = axes[row, col]
        ax.hist(position_data, bins=10, alpha=0.5)
        
        # Add red lines at the specified thresholds and count players above each threshold
        for idx, threshold in enumerate(thresholds):
            above_threshold_count = (position_data > threshold).sum()
            ax.axvline(x=threshold, color=threshold_colors[idx], linestyle='--', label=f'{threshold} (Above: {above_threshold_count})')
        
        ax.set_title(f'{position}')
        ax.set_xlabel('Player Value')
        ax.set_ylabel('Number of Players')
        
        # Set the legend font size
        legend = ax.legend()
        for item in legend.get_texts():
            item.set_fontsize(legend_fontsize)

    # Hide any empty subplots if the number of positions is not a multiple of num_cols
    for i in range(len(positions), num_rows * num_cols):
        row = i // num_cols
        col = i % num_cols
        fig.delaxes(axes[row, col])

    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

# %%
plot_player_value_distribution(df, ['GK', 'DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'MR', 'ML', 'MC', 'AML', 'AMC', 'AMR', 'ST'], thresholds=[12, 18], legend_fontsize=14)

# %%
def plot_position_percentage_above_thresholds(df, thresholds, positions_to_visualize):
    """
    Plot the percentage of players in selected soccer positions with values above the specified thresholds compared to
    the total number of players.

    Parameters:
    df (DataFrame): The DataFrame containing player positions and values.
    thresholds (list): A list of threshold values.
    positions_to_visualize (list): A list of positions to visualize. If None, all positions will be visualized.

    Returns:
    None
    """
    if positions_to_visualize is None:
        positions_to_visualize = df.columns
    
    position_percentages = {position: [] for position in positions_to_visualize}

    for threshold in thresholds:
        for position in positions_to_visualize:
            above_threshold_count = (df[position] > threshold).sum()
            total_count = len(df)
            percentage = (above_threshold_count / total_count) * 100
            position_percentages[position].append(percentage)

    num_positions = len(positions_to_visualize)
    width = 0.35
    x = range(num_positions)

    fig, ax = plt.subplots(figsize=(12, 6))
    for i, threshold in enumerate(thresholds):
        bars = ax.bar(
            [pos + width * i for pos in x],
            [position_percentages[position][i] for position in positions_to_visualize],
            width,
            label=f'Above {threshold}',
        )
        
        # Add percentage labels above the bars
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}%', 
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(8, 3),  # 8, 3 points offset
                        textcoords="offset points",
                        ha='center', va='bottom')

    ax.set_xlabel('Soccer Positions')
    ax.set_ylabel('Percentage of Players')
    ax.set_title('Percentage of Players in Selected Soccer Positions Above Thresholds')
    ax.set_xticks([pos + width for pos in x])
    ax.set_xticklabels(positions_to_visualize)
    ax.legend(title='Thresholds')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
plot_position_percentage_above_thresholds(df, [12, 18], ['GK', 'DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'MR', 'ML', 'MC', 'AML', 'AMC', 'AMR', 'ST'])

# %%
def plot_player_skill_distribution(df, skills, legend_fontsize):
    """
    Plot the distribution of player skills for each skill in a grid of separate histograms,
    add red lines at the above average and above 75th percentile thresholds,
    and display the number of players above each threshold for each skill.

    Parameters:
    df (DataFrame): The DataFrame containing player skills and values.
    skills (list): A list of skill column names.
    legend_fontsize (int): Font size for the legend text.

    Returns:
    None
    """
    num_skills = len(skills)
    num_cols = 3  # Number of columns in the grid
    num_rows = (num_skills + num_cols - 1) // num_cols  # Calculate the number of rows needed

    # Define colors for the thresholds
    threshold_colors = ['orange', 'red']

    # Create a grid of subplots
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(25, 20))
    fig.suptitle('Distribution of Player Skills by Skill', fontsize=16)

    for i, skill in enumerate(skills):
        row = i // num_cols
        col = i % num_cols

        skill_data = df[skill]

        ax = axes[row, col]
        ax.hist(skill_data, bins=10, alpha=0.5)
        
        # Calculate the above average and above 75th percentile thresholds
        above_60th_percentile_threshold = skill_data.quantile(0.60)
        above_90th_percentile_threshold = skill_data.quantile(0.90)
        
        # Add red lines at the above 60th percentile and above 90th percentile thresholds
        for idx, threshold in enumerate([above_60th_percentile_threshold, above_90th_percentile_threshold]):
            above_threshold_count = (skill_data > threshold).sum()
            ax.axvline(x=threshold, color=threshold_colors[idx], linestyle='--', label=f'Above {threshold:.2f} (Above: {above_threshold_count})')
        
        ax.set_title(f'{skill}')
        ax.set_xlabel('Skill Value')
        ax.set_ylabel('Number of Players')
        
        # Set the legend font size
        legend = ax.legend()
        for item in legend.get_texts():
            item.set_fontsize(legend_fontsize)

    # Hide any empty subplots if the number of skills is not a multiple of num_cols
    for i in range(len(skills), num_rows * num_cols):
        row = i // num_cols
        col = i % num_cols
        fig.delaxes(axes[row, col])

    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

# %%
plot_player_skill_distribution(df, skills=["Corners", "Crossing", "Dribbling", "Finishing", "First Touch",
    "Free Kick Taking", "Heading", "Long Shots", "Passing", "Tackling",
    "Technique", "Concentration", "Vision", "Decision", "Determination",
    "Position.1","Teamwork", "Balance", "Natural Fitness", "Pace",
    "Stamina", "Strength", "Communication", "Reflexes", "Left Foot", "Right Foot"], legend_fontsize=14)

# %% [markdown]
# ### 2.2 Bivariate Analysis

# %%
def visualize_top_positive_correlations(df, positions_to_visualize, skills, top_n):
    """
    Visualize the top N highest positive correlations between soccer player position value and skills for each position.

    Parameters:
    df (DataFrame): The DataFrame containing player positions and skills.
    positions_to_visualize (list): A list of positions to visualize.
    skills (list): A list of skills to consider.
    top_n (int): Number of top positive correlations to visualize (default is 5).

    Returns:
    None
    """
    num_positions = len(positions_to_visualize)
    num_cols = 3  # Number of columns in the grid
    num_rows = (num_positions + num_cols - 1) // num_cols  # Calculate the number of rows needed

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10 * num_rows))
    fig.suptitle(f'Top {top_n} Highest Positive Correlations between Player Position Value and Skills', fontsize=16)

    for i, position in enumerate(positions_to_visualize):
        row = i // num_cols
        col = i % num_cols

        # Calculate the correlations between position value and each skill
        correlations = df[skills].corrwith(df[position])

        # Sort correlations in descending order
        top_correlations = correlations.sort_values(ascending=False).head(top_n)

        ax = axes[row, col]
        ax.barh(top_correlations.index, top_correlations.values, color='dodgerblue')
        ax.set_xlabel('Correlation Value')
        ax.set_title(f'Top {top_n} Positive Correlations for {position}')
        ax.invert_yaxis()  # Invert the y-axis for better visualization

    # Hide any empty subplots if the number of positions is not a multiple of num_cols
    for i in range(len(positions_to_visualize), num_rows * num_cols):
        row = i // num_cols
        col = i % num_cols
        fig.delaxes(axes[row, col])

    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

# %%
positions_to_visualize = ['GK', 'DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'MR', 'ML', 'MC', 'AML', 'AMC', 'AMR', 'ST']

skills_to_visualize = ["Corners", "Crossing", "Dribbling", "Finishing", "First Touch",
    "Free Kick Taking", "Heading", "Long Shots", "Passing", "Tackling",
    "Technique", "Concentration", "Vision", "Decision", "Determination",
    "Position.1","Teamwork", "Balance", "Natural Fitness", "Pace",
    "Stamina", "Strength", "Communication", "Reflexes", "Left Foot", "Right Foot"]

top_n = 10

visualize_top_positive_correlations(df, positions_to_visualize, skills_to_visualize, top_n)

# %%
df = df[(df['GK'] <= 10)]

# %%
df
# Out:
#                     Name  Corners  Crossing  Dribbling  Finishing  \
# 0        Kevin De Bruyne       14        19         15         16
# 1          Kylian Mbappé       13        13         18         17
# 2     Robert Lewandowski        3         8         13         19
# 3         Erling Haaland        7        10         14         18
# 4          Mohamed Salah       12        14         17         17
# ...                  ...      ...       ...        ...        ...
# 8447          Joe Ashton        3         4          5          4
# 8448          River Ries        2         2         11         11
# 8449      Halilcan Doğan        1         1          1          2
# 8450        Adijat Sefer        3         4         12          7
# 8451         Linus Urban        4         2         10         13
#
#       First Touch  Free Kick Taking  Heading  Long Shots  Passing  ...  WBL  \
# 0              16                17        6          17       18  ...    1
# ...

# %%
import pandas as pd
import scipy.stats

def top_skills_by_position(df, positions, skills):

    position_skills_dict = {}

    for position in positions:
        spearman_corr, p_values = [], []

        for skill in skills:
            spearman_corr_val, p_value = scipy.stats.spearmanr(df[skill], df[position])
            spearman_corr.append(spearman_corr_val)
            p_values.append(p_value)

        results_df = pd.DataFrame({'Skill': skills, 'Spearman_Corr': spearman_corr, 'P_Value': p_values})
        significant_skills = results_df[results_df['P_Value'] < 0.05].sort_values(
            by='Spearman_Corr', ascending=False).head(top_n)['Skill'].tolist()

        position_skills_dict[position] = significant_skills

    return position_skills_dict

# %%
# def top_skills_by_position(df, positions, skills, top_n=10):
#     """
#     Create a dictionary that associates each soccer player position with its top N skills based on correlations.

#     Parameters:
#     df (DataFrame): The DataFrame containing player positions and skills.
#     positions (list): A list of positions to consider.
#     skills (list): A list of skills to consider.
#     top_n (int): Number of top skills to associate with each position (default is 10).

#     Returns:
#     dict: A dictionary where keys are positions, and values are lists of top N skills.
#     """
#     position_skills_dict = {}

#     for position in positions:
#         correlations = df[skills].corrwith(df[position])
#         top_skills = correlations.sort_values(ascending=False).head(top_n).index.tolist()
#         position_skills_dict[position] = top_skills

#     return position_skills_dict

# Usage example:
positions = ['DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'MR', 'ML', 'MC', 'AML', 'AMC', 'AMR', 'ST']

skills = ["Corners", "Crossing", "Dribbling", "Finishing", "First Touch",
    "Free Kick Taking", "Heading", "Long Shots", "Passing", "Tackling",
    "Technique", "Concentration", "Vision", "Decision", "Determination",
    "Position.1","Teamwork", "Balance", "Natural Fitness", "Pace",
    "Stamina", "Strength", "Communication", "Reflexes", "Left Foot", "Right Foot"]

top_skills = top_skills_by_position(df, positions, skills)

# %%
top_skills
# Out:
# {'DL': ['Tackling',
#   'Left Foot',
#   'Position.1',
#   'Stamina',
#   'Crossing',
#   'Teamwork',
#   'Pace',
#   'Concentration',
#   'Strength',
#   'Natural Fitness'],
#  'DC': ['Tackling',
#   'Position.1',
#   'Heading',
#   'Strength',
#   'Concentration',
#   'Teamwork',
#   'Balance',
#   'Stamina',
#   'Determination',
#   'Natural Fitness'],
#  'DR': ['Tackling',
#   'Position.1',
#   'Stamina',
#   'Right Foot',
#   'Teamwork',
#   'Strength',
#   'Concentration',
#   'Pace',
#   'Heading',
#   'Natural Fitness'],
#  'WBL': ['Crossing',
#   'Left Foot',
#   'Tackling',
#   'Pace',
#   'Stamina',
#   'Position.1',
#   'Teamwork',
#   'Corners',
#   'Natural Fitness',
#   'Determination'],
#  'WBR': ['Tackling',
#   'Crossing',
#   'Pace',
#   'Stamina',
#   'Right Foot',
#   'Position.1',
#   'Teamwork',
#   'Natural Fitness',
#   'Determination',
#   'Concentration'],
#  'DM': ['Position.1',
#   'Tackling',
#   'Teamwork',
#   'Passing',
#   'Concentration',
# ...

# %%
all_skills_with_positions = {}
for position, skills_list in top_skills.items():
    for skill in skills_list:
        if skill in all_skills_with_positions:
            all_skills_with_positions[skill].append(position)
        else:
            all_skills_with_positions[skill] = [position]

all_skills_with_positions
# Out:
# {'Tackling': ['DL', 'DC', 'DR', 'WBL', 'WBR', 'DM'],
#  'Left Foot': ['DL', 'WBL', 'ML'],
#  'Position.1': ['DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'MC'],
#  'Stamina': ['DL', 'DC', 'DR', 'WBL', 'WBR', 'DM'],
#  'Crossing': ['DL', 'WBL', 'WBR', 'MR', 'ML', 'AML', 'AMC', 'AMR'],
#  'Teamwork': ['DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'MC'],
#  'Pace': ['DL', 'DR', 'WBL', 'WBR', 'MR', 'ML', 'AML', 'AMR', 'ST'],
#  'Concentration': ['DL', 'DC', 'DR', 'WBR', 'DM'],
#  'Strength': ['DL', 'DC', 'DR', 'DM'],
#  'Natural Fitness': ['DL', 'DC', 'DR', 'WBL', 'WBR'],
#  'Heading': ['DC', 'DR', 'ST'],
#  'Balance': ['DC'],
#  'Determination': ['DC', 'WBL', 'WBR'],
#  'Right Foot': ['DR', 'WBR', 'DM', 'ST'],
#  'Corners': ['WBL', 'MR', 'ML', 'MC', 'AML', 'AMC', 'AMR', 'ST'],
#  'Passing': ['DM', 'MC', 'AMC'],
#  'Decision': ['DM', 'MC'],
#  'Vision': ['DM', 'MR', 'ML', 'MC', 'AML', 'AMC', 'AMR'],
#  'Dribbling': ['MR', 'ML', 'AML', 'AMC', 'AMR', 'ST'],
# ...

# %%
import numpy as np
from collections import Counter

# %%
def calculate_position_percentages(skill_positions, position_categories):
    skill_percentage_dict = {}

    for skill, positions in skill_positions.items():
        category_counts = Counter()
        
        for category, category_positions in position_categories.items():
            category_count = sum(1 for pos in positions if pos in category_positions)
            category_percentage = (category_count / len(category_positions)) * 100
            category_counts[category] = category_percentage

        skill_percentage_dict[skill] = category_counts

    return skill_percentage_dict

# %%
def plot_position_percentages(skill_percentage_dict):
    skills = list(skill_percentage_dict.keys())
    num_skills = len(skills)
    num_columns = 3  # Number of columns in the grid
    num_rows = (num_skills + num_columns - 1) // num_columns

    # Define colors for each skill
    colors = plt.cm.viridis(np.linspace(0, 1, num_skills))

    fig, axes = plt.subplots(num_rows, num_columns, figsize=(15, 6 * num_rows))
    fig.suptitle('Position Percentage for Each Skill', fontsize=16)

    for i, skill in enumerate(skills):
        row = i // num_columns
        col = i % num_columns
        percentages = skill_percentage_dict[skill]
        categories = list(percentages.keys())
        values = list(percentages.values())

        ax = axes[row, col]
        ax.barh(categories, values, color=colors[i], label=skill)
        ax.set_xlabel('Percentage')
        ax.set_title(f'Skill: {skill}')
        ax.legend(loc='best')

    # Hide any empty subplots if the number of skills is not a multiple of num_columns
    for i in range(num_skills, num_rows * num_columns):
        row = i // num_columns
        col = i % num_columns
        fig.delaxes(axes[row, col])

    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

# %% [markdown]
# ##### Difference Between DC, DL, DR, WBR, WBL

# %%
# Dictionary with your categorization of positions
position_categories = {
    'DC': ['DC'],
    'DL, DR': ['DL', 'DR'],
    'WBR or WBL': ['WBR', 'WBL']
}

# %%
skill_percentage_result = calculate_position_percentages(all_skills_with_positions, position_categories)

# %%
plot_position_percentages(skill_percentage_result)

# %%
# Dictionary with your categorization of positions
position_categories = {
    'MC': ['MC'],
    'DM': ['DM'],
    'MR or ML': ['MR', 'ML']
}

# %%
skill_percentage_result = calculate_position_percentages(all_skills_with_positions, position_categories)

# %%
plot_position_percentages(skill_percentage_result)

# %%
position_categories = {
    'AMC': ['AMC'],
    'AML or AMR': ['AML', 'AMR'],
    'ST': ['ST']
}

# %%
skill_percentage_result = calculate_position_percentages(all_skills_with_positions, position_categories)

# %%
plot_position_percentages(skill_percentage_result)

# %% [markdown]
# ### 2.3. Detect Missing Values

# %%
df.isna().sum()
# Out:
# Name                0
# Corners             0
# Crossing            0
# Dribbling           0
# Finishing           0
# First Touch         0
# Free Kick Taking    0
# Heading             0
# Long Shots          0
# Passing             0
# Tackling            0
# Technique           0
# Concentration       0
# Vision              0
# Decision            0
# Determination       0
# Position.1          0
# Teamwork            0
# Balance             0
# Natural Fitness     0
# Pace                0
# Stamina             0
# Strength            0
# Communication       0
# Reflexes            0
# Left Foot           0
# Right Foot          0
# GK                  0
# DL                  0
# DC                  0
# DR                  0
# WBL                 0
# WBR                 0
# DM                  0
# MR                  0
# ML                  0
# MC                  0
# AML                 0
# AMC                 0
# AMR                 0
# ST                  0
# dtype: int64

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Feature Engineering

# %%
# Define the skill groups
skill_groups = {
    'bertahan': ['Tackling', 'Position.1', 'Stamina', 'Teamwork', 'Natural Fitness'],
    'menyerang': ['Crossing', 'Dribbling', 'Technique', 'Free Kick Taking', 'Long Shots', 'Finishing', 'First Touch'],
}

# %%
offense_defense = pd.DataFrame()

# Iterate through the skill groups and calculate the sum of skills in each group
for group, skills in skill_groups.items():
    offense_defense[group] = sum(df[skill] for skill in skills)

# Create a list of excluded skills
excluded_skills = [skill for skills in df.keys() if skill not in skill_groups]

# Add the remaining columns to the grouped DataFrame, excluding the excluded skills
for position in excluded_skills:
    offense_defense[position] = df[position]

# Display the grouped DataFrame
offense_defense
# Out:
#       bertahan  menyerang  Corners
# 0           67        118       14
# 1           46        108       13
# 2           64        101        3
# 3           60         99        7
# 4           63        107       12
# ...        ...        ...      ...
# 8447        51         25        3
# 8448        25         44        2
# 8449        39         13        1
# 8450        23         48        3
# 8451        25         45        4
#
# [7755 rows x 3 columns]

# %%
offense_defense = offense_defense[['bertahan', 'menyerang']]

# %%
# Define the skill groups
skill_groups = {
    'bertahan': ['Tackling', 'Position.1', 'Stamina', 'Teamwork', 'Natural Fitness'],
    'menyerang': ['Crossing', 'Dribbling', 'Long Shots', 'First Touch', 'Technique', 'Free Kick Taking', 'Finishing'],
}
total_skills = ["Corners", "Crossing", "Dribbling", "Finishing", "First Touch",
    "Free Kick Taking", "Heading", "Long Shots", "Passing", "Tackling",
    "Technique", "Concentration", "Vision", "Decision", "Determination",
    "Position.1","Teamwork", "Balance", "Natural Fitness", "Pace",
    "Stamina", "Strength", "Left Foot", "Right Foot"]

# Create a set of all skills in skill_groups
all_skills_in_groups = set(skill for skills in skill_groups.values() for skill in skills)

# Find the missing skill
missing_skill = set(total_skills) - all_skills_in_groups

print("The missing skill in skill_groups is:", missing_skill)
# Out:
# The missing skill in skill_groups is: {'Left Foot', 'Balance', 'Vision', 'Passing', 'Right Foot', 'Concentration', 'Corners', 'Heading', 'Pace', 'Determination', 'Decision', 'Strength'}

# %%
df_merged = offense_defense

df_merged[['Name','Determination', 'Balance', 'Heading', 'Pace', 'Corners', 'Right Foot', 'Strength', 
           'Concentration', 'Vision', 'Decision', 'Passing', 'Left Foot', 'DL', 
           'DC', 'DR', 'WBL', 'WBR', 'DM', 'MR', 'ML', 
           'MC', 'AML', 'AMC', 'AMR', 'ST']] = df[['Name','Determination', 'Balance', 'Heading', 'Pace', 
                                                   'Corners', 'Right Foot', 
                                                   'Strength', 'Concentration', 'Vision', 
                                                   'Decision', 'Passing', 'Left Foot', 'DL', 
                                                   'DC', 'DR', 'WBL', 'WBR','DM', 'MR', 'ML', 
                                                   'MC', 'AML', 'AMC', 'AMR', 'ST']]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7755 entries, 0 to 8451
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bertahan       7755 non-null   int64
#  1   menyerang      7755 non-null   int64
#  2   Name           7755 non-null   object
#  3   Determination  7755 non-null   int64
#  4   Balance        7755 non-null   int64
#  5   Heading        7755 non-null   int64
#  6   Pace           7755 non-null   int64
#  7   Corners        7755 non-null   int64
#  8   Right Foot     7755 non-null   int64
#  9   Strength       7755 non-null   int64
#  10  Concentration  7755 non-null   int64
#  11  Vision         7755 non-null   int64
#  12  Decision       7755 non-null   int64
#  13  Passing        7755 non-null   int64
#  14  Left Foot      7755 non-null   int64
#  15  DL             7755 non-null   int64
#  16  DC             7755 non-null   int64
#  17  DR             7755 non-null   int64
# ...

# %%
df_merged[['Determination', 'Balance', 'Heading', 'Pace', 'Corners', 'Right Foot', 
           'Strength', 'Concentration', 'Vision', 'Decision', 'Passing', 'Left Foot']].corr()
# Out:
#                Determination   Balance   Heading      Pace   Corners  \
# Determination       1.000000  0.252000  0.129720  0.045282 -0.023372
# Balance             0.252000  1.000000  0.322642  0.067687  0.004742
# Heading             0.129720  0.322642  1.000000 -0.111986 -0.440502
# Pace                0.045282  0.067687 -0.111986  1.000000  0.039447
# Corners            -0.023372  0.004742 -0.440502  0.039447  1.000000
# Right Foot          0.026599  0.022055  0.066747 -0.044684 -0.148153
# Strength            0.253335  0.553910  0.640349 -0.000322 -0.267152
# Concentration       0.283038  0.431394  0.328465 -0.041013  0.056031
# Vision              0.107571  0.192475 -0.259062 -0.041747  0.508453
# Decision            0.104930  0.191700  0.157701 -0.214489  0.089214
# Passing             0.123990  0.233335 -0.166871 -0.067186  0.427793
# Left Foot          -0.007296  0.002047 -0.092840  0.031818  0.207952
#
# ...

# %%
df_merged.drop(columns=['Strength'], inplace=True)

# %%
skills = ['Passing', 'Vision', 'Corners']

df_merged['Playmaking'] = sum(df[skill] for skill in skills)

# %%
df_merged.drop(columns=['Passing', 'Vision', 'Corners'], inplace=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7755 entries, 0 to 8451
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bertahan       7755 non-null   int64
#  1   menyerang      7755 non-null   int64
#  2   Name           7755 non-null   object
#  3   Determination  7755 non-null   int64
#  4   Balance        7755 non-null   int64
#  5   Heading        7755 non-null   int64
#  6   Pace           7755 non-null   int64
#  7   Right Foot     7755 non-null   int64
#  8   Concentration  7755 non-null   int64
#  9   Decision       7755 non-null   int64
#  10  Left Foot      7755 non-null   int64
#  11  DL             7755 non-null   int64
#  12  DC             7755 non-null   int64
#  13  DR             7755 non-null   int64
#  14  WBL            7755 non-null   int64
#  15  WBR            7755 non-null   int64
#  16  DM             7755 non-null   int64
#  17  MR             7755 non-null   int64
# ...

# %%
df_merged[['Heading', 'Determination', 'Balance', 
            'Decision', 'Concentration', 'Pace', 'Playmaking']].corr()
# Out:
#                 Heading  Determination   Balance  Decision  Concentration  \
# Heading        1.000000       0.129720  0.322642  0.157701       0.328465
# Determination  0.129720       1.000000  0.252000  0.104930       0.283038
# Balance        0.322642       0.252000  1.000000  0.191700       0.431394
# Decision       0.157701       0.104930  0.191700  1.000000       0.437427
# Concentration  0.328465       0.283038  0.431394  0.437427       1.000000
# Pace          -0.111986       0.045282  0.067687 -0.214489      -0.041013
# Playmaking    -0.377346       0.067015  0.147532  0.268183       0.190059
#
#                    Pace  Playmaking
# Heading       -0.111986   -0.377346
# Determination  0.045282    0.067015
# Balance        0.067687    0.147532
# Decision      -0.214489    0.268183
# Concentration -0.041013    0.190059
# Pace           1.000000   -0.016215
# Playmaking    -0.016215    1.000000

# %%
df_merged
# Out:
#       bertahan  menyerang                Name  Determination  Balance  \
# 0           67        118     Kevin De Bruyne             17       14
# 1           46        108       Kylian Mbappé             15       15
# 2           64        101  Robert Lewandowski             20       19
# 3           60         99      Erling Haaland             20       17
# 4           63        107       Mohamed Salah             18       18
# ...        ...        ...                 ...            ...      ...
# 8447        51         25          Joe Ashton             11        6
# 8448        25         44          River Ries             11        2
# 8449        39         13      Halilcan Doğan             13        4
# 8450        23         48        Adijat Sefer              4        4
# 8451        25         45         Linus Urban             16        5
#
#       Heading  Pace  Right Foot  Concentration  Decision  ...  WBR  DM  MR  \
# ...

# %%
# Define the skill groups
positional_tendencies = {
    'posisi_bertahan': ['DL', 'DC', 'DR', 'WBL', 'WBR'],
    'posisi_gelandang': ['DM', 'MR', 'ML', 'MC'],
    'posisi_menyerang': ['AML', 'AMC', 'AMR', 'ST'],
}

# %%
position_categorical = pd.DataFrame()

# Iterate through the skill groups and calculate the sum of skills in each group
for group, positions in positional_tendencies.items():
    position_max = df[positions].max(axis=1)
    position_categorical[group] = (position_max > 12).astype(int)

# Display the grouped DataFrame
position_categorical
# Out:
#       posisi_bertahan  posisi_gelandang  posisi_menyerang
# 0                   0                 1                 1
# 1                   0                 0                 1
# 2                   0                 0                 1
# 3                   0                 0                 1
# 4                   0                 0                 1
# ...               ...               ...               ...
# 8447                1                 0                 0
# 8448                0                 0                 1
# 8449                1                 0                 0
# 8450                0                 0                 1
# 8451                0                 0                 1
#
# [7755 rows x 3 columns]

# %%
df_merged[['posisi_bertahan', 'posisi_gelandang', 'posisi_menyerang']] = position_categorical[['posisi_bertahan', 'posisi_gelandang', 'posisi_menyerang']]

# %%
df_merged
# Out:
#       bertahan  menyerang                Name  Determination  Balance  \
# 0           67        118     Kevin De Bruyne             17       14
# 1           46        108       Kylian Mbappé             15       15
# 2           64        101  Robert Lewandowski             20       19
# 3           60         99      Erling Haaland             20       17
# 4           63        107       Mohamed Salah             18       18
# ...        ...        ...                 ...            ...      ...
# 8447        51         25          Joe Ashton             11        6
# 8448        25         44          River Ries             11        2
# 8449        39         13      Halilcan Doğan             13        4
# 8450        23         48        Adijat Sefer              4        4
# 8451        25         45         Linus Urban             16        5
#
#       Heading  Pace  Right Foot  Concentration  Decision  ...  ML  MC  AML  \
# ...

# %%
df_merged = df_merged[~((df_merged['defensive'] == 0) & (df_merged['midfielder'] == 0) & (df_merged['offensive'] == 0))]

# %%
df_merged
# Out:
#       defense  offense                Name  Determination  Balance  Heading  \
# 0          67      118     Kevin De Bruyne             17       14        6
# 1          46      108       Kylian Mbappé             15       15        7
# 2          64      101  Robert Lewandowski             20       19       17
# 3          60       99      Erling Haaland             20       17       15
# 4          63      107       Mohamed Salah             18       18       10
# ...       ...      ...                 ...            ...      ...      ...
# 8447       51       25          Joe Ashton             11        6        6
# 8448       25       44          River Ries             11        2        6
# 8449       39       13      Halilcan Doğan             13        4       12
# 8450       23       48        Adijat Sefer              4        4       12
# 8451       25       45         Linus Urban             16        5       13
#
# ...

# %% [markdown]
# ## First Model

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import make_scorer, hamming_loss
from sklearn.preprocessing import MinMaxScaler
from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit
from sklearn.utils import indexable, _safe_indexing
from sklearn.utils.validation import _num_samples
from sklearn.model_selection._split import _validate_shuffle_split
from itertools import chain
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
df_merged.reset_index().drop(columns=["index"], inplace=True)

# %%
X_1 = df_merged[['defense', 'offense']]
y_1 = df_merged[['defensive', 'midfielder', 'offensive']]

# %%
def multilabel_train_test_split(*arrays,
                                test_size=None,
                                train_size=None,
                                random_state=None,
                                shuffle=True,
                                stratify=None):
    """
    Train test split for multilabel classification. Uses the algorithm from: 
    'Sechidis K., Tsoumakas G., Vlahavas I. (2011) On the Stratification of Multi-Label Data'.
    """
    if stratify is None:
        return train_test_split(*arrays, test_size=test_size,train_size=train_size,
                                random_state=random_state, stratify=None, shuffle=shuffle)
    
    assert shuffle, "Stratified train/test split is not implemented for shuffle=False"
    
    n_arrays = len(arrays)
    arrays = indexable(*arrays)
    n_samples = _num_samples(arrays[0])
    n_train, n_test = _validate_shuffle_split(
        n_samples, test_size, train_size, default_test_size=0.25
    )
    cv = MultilabelStratifiedShuffleSplit(test_size=n_test, train_size=n_train, random_state=123)
    train, test = next(cv.split(X=arrays[0], y=stratify))

    return list(
        chain.from_iterable(
            (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
        )
    )

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = multilabel_train_test_split(X_1, y_1, stratify=y_1, test_size = 0.3)

# %%
scaler = MinMaxScaler()
classifier = MultiOutputClassifier(KNeighborsClassifier())
cv = RepeatedKFold(n_splits=5, n_repeats=5, random_state=42)

# %%
pipeline = Pipeline([
    ('scaler', scaler),           
    ('classifier', classifier)  
])

# Step 4: Define the hyperparameter grid for tuning
param_grid = {
    'classifier__estimator__n_neighbors': [5, 7, 9],
    'classifier__estimator__weights': ['uniform', 'distance']
}


scoring = make_scorer(hamming_loss, greater_is_better=False)

grid_search = GridSearchCV(pipeline, param_grid, cv=cv, scoring=scoring)

grid_search.fit(X_train_1, y_train_1) 


best_pipeline = grid_search.best_estimator_
best_params = grid_search.best_params_

# %%
best_pipeline
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('classifier',
#                  MultiOutputClassifier(estimator=KNeighborsClassifier(n_neighbors=9)))])

# %%
scores = cross_val_score(best_pipeline, X_test_1, y_test_1, scoring=scoring, cv=cv)
# force scores to be positive
scores=np.abs(scores)
print('Mean Hamming Loss: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# Mean Hamming Loss: 0.230 (0.010)

# %%
scores
# Out:
# array([0.23542117, 0.23470122, 0.23470122, 0.22462203, 0.24478042,
#        0.2325414 , 0.21310295, 0.2462203 , 0.23614111, 0.20518359,
#        0.24118071, 0.22390209, 0.23542117, 0.2224622 , 0.21958243,
#        0.22894168, 0.23326134, 0.23326134, 0.2275018 , 0.22822174,
#        0.23470122, 0.24766019, 0.21382289, 0.22678186, 0.23470122])

# %%
predicts_1 = best_pipeline.predict(X_test_1)

# %%
hamming_loss(y_test_1, predicts_1)
# Out:
# 0.23484521238300937

# %% [markdown]
# ## Defensive Model

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7755 entries, 0 to 8451
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   defense        7755 non-null   int64
#  1   offense        7755 non-null   int64
#  2   Name           7755 non-null   object
#  3   Determination  7755 non-null   int64
#  4   Balance        7755 non-null   int64
#  5   Heading        7755 non-null   int64
#  6   Pace           7755 non-null   int64
#  7   Right Foot     7755 non-null   int64
#  8   Concentration  7755 non-null   int64
#  9   Decision       7755 non-null   int64
#  10  Left Foot      7755 non-null   int64
#  11  DL             7755 non-null   int64
#  12  DC             7755 non-null   int64
#  13  DR             7755 non-null   int64
#  14  WBL            7755 non-null   int64
#  15  WBR            7755 non-null   int64
#  16  DM             7755 non-null   int64
#  17  MR             7755 non-null   int64
# ...

# %%
X_2 = df_merged[df_merged['defensive'] == 1][['Determination', 'Balance', 'Heading', 'Pace',
                                             'Right Foot', 'Concentration', 'Decision', 'Left Foot',
                                             'Playmaking']]
y_2 = df_merged[df_merged['defensive'] == 1][['DL', 'DC', 'DR', 'WBL', 'WBR']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2, test_size=0.3, random_state=42)

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from numpy import absolute

# %%
regressor = XGBRegressor()
cv_regressor = RepeatedKFold(n_splits=5, n_repeats=5, random_state=42)

# %%
param_grid = {
    'n_estimators': [100],  
    'max_depth': [6, 8, 10],         
    'eta': [0.05, 0.3, 0.55]
}


scoring_regression = make_scorer(mean_absolute_error, greater_is_better=False)

grid_search_reg = GridSearchCV(regressor, param_grid, cv=cv_regressor, scoring=scoring_regression)

grid_search_reg.fit(X_train_2, y_train_2) 


best_pipeline_reg = grid_search_reg.best_estimator_
best_params_reg = grid_search_reg.best_params_

# %%
scores = cross_val_score(best_pipeline_reg, X_test_2, y_test_2, scoring='neg_mean_absolute_error', cv=cv_regressor)
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# Mean MAE: 3.843 (0.137)

# %%
scores
# Out:
# array([3.63179428, 4.07932463, 3.8705456 , 3.85897975, 3.79571191,
#        3.82740983, 3.73012254, 4.14778067, 3.80832188, 3.81481071,
#        3.83997732, 3.86574751, 3.65436248, 3.97949804, 3.84373774,
#        4.05581986, 3.9712996 , 3.84903365, 3.9499917 , 3.55635661,
#        3.85327688, 3.9161952 , 3.68682222, 3.72681332, 3.75794593])

# %%
predictions = best_pipeline_reg.predict(X_test_2)

# %%
mean_absolute_error(y_test_2, predictions)
# Out:
# 3.7345808412324173

# %%
residuals = y_test_2 - predictions
standardized_residuals = residuals / np.std(residuals)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test_2, standardized_residuals, c='b', alpha=0.5)
plt.xlabel('True Values')
plt.ylabel('Residuals')
plt.title('True Values vs. Residuals')
plt.grid(True)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %% [markdown]
# ## Midfielder Model

# %%
X_3 = df_merged[df_merged['midfielder'] == 1][['Determination', 'Balance', 'Heading', 'Pace',
                                             'Right Foot', 'Concentration', 'Decision', 'Left Foot',
                                             'Playmaking']]
y_3 = df_merged[df_merged['midfielder'] == 1][['DM', 'MR', 'ML','MC']]

# %%
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X_3, y_3, test_size=0.3, random_state=42)

# %%
param_grid = {
    'n_estimators': [100],  
    'max_depth': [6, 8, 10],         
    'eta': [0.05, 0.3, 0.55]
}


scoring_regression = make_scorer(mean_absolute_error, greater_is_better=False)

grid_search_reg_2 = GridSearchCV(regressor, param_grid, cv=cv_regressor, scoring=scoring_regression)

grid_search_reg_2.fit(X_train_3, y_train_3) 


best_pipeline_reg_2 = grid_search_reg_2.best_estimator_
best_params_reg_2 = grid_search_reg_2.best_params_

# %%
scores = cross_val_score(best_pipeline_reg_2, X_test_3, y_test_3, scoring='neg_mean_absolute_error', cv=cv_regressor)
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# Mean MAE: 5.034 (0.129)

# %%
scores
# Out:
# array([4.76151162, 5.23675493, 4.99088269, 5.00649339, 5.10377342,
#        4.93085927, 5.29632364, 5.08046682, 5.15260467, 4.92773916,
#        5.13690397, 4.88628951, 5.0599533 , 5.03370683, 5.03270955,
#        4.92336612, 4.98722597, 5.12004771, 4.96535177, 5.00489678,
#        4.95347286, 5.32784884, 5.08431002, 4.87909293, 4.96012158])

# %%
predictions = best_pipeline_reg_2.predict(X_test_3)

# %%
mean_absolute_error(y_test_3, predictions)
# Out:
# 5.0232294879354775

# %% [markdown]
# ## Attacker Model

# %%
X_4 = df_merged[df_merged['offensive'] == 1][['Determination', 'Balance', 'Heading', 'Pace',
                                             'Right Foot', 'Concentration', 'Decision', 'Left Foot',
                                             'Playmaking']]
y_4 = df_merged[df_merged['offensive'] == 1][['AMR', 'AMC', 'AML', 'ST']]

# %%
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(X_4, y_4, test_size=0.3, random_state=42)

# %%
param_grid = {
    'n_estimators': [100],  
    'max_depth': [6, 8, 10],         
    'eta': [0.05, 0.3, 0.55]
}


scoring_regression = make_scorer(mean_absolute_error, greater_is_better=False)

grid_search_reg_3 = GridSearchCV(regressor, param_grid, cv=cv_regressor, scoring=scoring_regression)

grid_search_reg_3.fit(X_train_4, y_train_4) 


best_pipeline_reg_3 = grid_search_reg_3.best_estimator_
best_params_reg_3 = grid_search_reg_3.best_params_

# %%
scores = cross_val_score(best_pipeline_reg_3, X_test_4, y_test_4, scoring='neg_mean_absolute_error', cv=cv_regressor)
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# Mean MAE: 5.165 (0.131)

# %%
scores
# Out:
# array([5.0877683 , 5.02430915, 5.33775062, 5.19812765, 5.09588538,
#        5.0678853 , 5.27927551, 4.91357123, 5.22517652, 5.27949404,
#        5.27417948, 5.11594242, 5.20046046, 5.04562204, 5.28993348,
#        5.05240163, 5.42408723, 5.21543383, 5.04558048, 5.15858332,
#        5.00495575, 5.29044169, 5.06736992, 5.03129269, 5.3987937 ])

# %%
predictions = best_pipeline_reg_3.predict(X_test_4)

# %%
mean_absolute_error(y_test_4, predictions)
# Out:
# 5.103453368434076
